# %% [markdown]
# ## Great, now that we discussed a little let's continue

# %% [markdown]
# Given that the current approach utilized by the authors lacks reproducibility, we will explore an alternative method by leveraging nf-core pipelines for data analysis.
#
# Please explain, how we will achieve reproducibility for the course  with this approach.
# -> nf-core provides a community curated, peer reviewed, standardised bioinformatics pipeline, so we can execute a standardised pipeline.

# %% [markdown]
# You have successfully downloaded 2 of the fastq files we will use in our study.
#
# What is the next step if we want to first have a count table and check the quality of our fastq files? What is the pipeline called to do so?
# -> The next step is to run the nf-core/rnaseq pipeline, which will perform quality control on the FASTQ files and generate a counts table.

# %% [markdown]
# Analyze the 2 files using an nf-core pipeline.
#
# What does this pipeline do?
#
# Which are the main tools that will be used in the pipeline?

# %% [markdown]
# nf-core/rnaseq performs RNA seq analysis from raw FASTQ files through quality control, alignment, quantification, and generates a final counts table along with quality reports.
#
# FastQC, Trim Galore!, STAR, HISAT2, Salmon, RSEM, SAMtools, UMI-tools, picard, StringTie, BEDTools, RSeQC, Qualimap, dupRadar, Preseq, DESeq2, Kraken2, Bracken, Kallisto, and MultiQC.

# %% [markdown]
# As all other nf-core pipelines, the chosen pipeline takes in a samplesheet as input.
#
# Use Python and pandas to create the samplesheet for your 2 samples. Feel free to make use of the table you created earlier today.
#
# Choose your sample names wisely, they must be the connection of the results to the metadata. If you can't find the sample in the metadata later, the analysis was useless.

# %%
# post here the command you used to run nf-core/rnaseq

# !nextflow run nf-core/rnaseq \
    -r 3.21.0 \
    -profile wsl_apptainer \
    -c test.config \
    --input samplesheet.csv \
    --genome GRCm38 \
    --outdir ./results \
     -resume
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/rnaseq` [boring_lamarr] DSL2 - revision: 9738a2df42 [3.21.0]
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/rnaseq 3.21.0
# ------------------------------------------------------
# Input/output options
#   input              : samplesheet.csv
#   outdir             : ./results
#
# Reference genome options
#   genome             : GRCm38
#   fasta              : s3://ngi-igenomes/igenomes//Mus_musculus/Ensembl/GRCm38/Sequence/WholeGenomeFasta/genome.fa
#   gtf                : s3://ngi-igenomes/igenomes//Mus_musculus/Ensembl/GRCm38/Annotation/Genes/genes.gtf
#   gene_bed           : s3://ngi-igenomes/igenomes//Mus_musculus/Ensembl/GRCm38/Annotation/Genes/genes.bed
#   star_index         : s3://ngi-igenomes/igenomes//Mus_musculus/Ensembl/GRCm38/Sequence/STARIndex/
#
# UMI options
#   umi_discard_read   : 0
#
# Process skipping options
#   skip_rseqc         : true
#
# Generic options
#   trace_report_suffix: 2025-09-30_15-28-03
#
# Core Nextflow options
#   revision           : 3.21.0
#   runName            : boring_lamarr
#   containerEngine    : apptainer
#   launchDir          : /home/mj/nf-pipelines/computational-workflows-2025/notebooks/day_02
#   workDir            : /home/mj/nf-pipelines/computational-workflows-2025/notebooks/day_02/work
#   projectDir         : /home/mj/.nextflow/assets/nf-core/rnaseq
#   userName           : mj
#   profile            : wsl_apptainer
#   configFiles        : /home/mj/.nextflow/assets/nf-core/rnaseq/nextflow.config, /home/mj/nf-pipelines/computational-workflows-2025/notebooks/day_02/test.config
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# * The pipeline
#     https://doi.org/10.5281/zenodo.1400710
#
# * The nf-core framework
#     https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#     https://github.com/nf-core/rnaseq/blob/master/CITATIONS.md
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 2 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 6 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 12 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 19 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 20 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 21 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT | 0 of 2
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 21 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
# ERROR ~ Error executing process > 'NFCORE_RNASEQ:RNASEQ:FASTQ_QC_TRIM_FILTER_SETSTRANDEDNESS:FQ_LINT (Sham-Oxy)'
#
# Caused by:
#   Process requirement exceeds available memory -- req: 12 GB; avail: 7.6 GB
#
#
# Command executed:
#
#   fq lint \
#       --disable-validator P001 \
#       SRX19144488_SRR23195511_1.fastq.gz SRX19144488_SRR23195511_2.fastq.gz > Sham-Oxy.fq_lint.txt
#
#   cat <<-END_VERSIONS > versions.yml
#   "NFCORE_RNASEQ:RNASEQ:FASTQ_QC_TRIM_FILTER_SETSTRANDEDNESS:FQ_LINT":
#       fq: $(echo $(fq lint --version | sed 's/fq-lint //g'))
#   END_VERSIONS
#
# Command exit status:
#   -
#
# Command output:
#   (empty)
#
# Work dir:
#   /home/mj/nf-pipelines/computational-workflows-2025/notebooks/day_02/work/3b/469f2a596f308dd8727be827d94075
#
# Container:
#   /home/mj/nf-pipelines/computational-workflows-2025/notebooks/day_02/work/singularity/quay.io-biocontainers-fq-0.12.0--h9ee0642_0.img
#
# Tip: you can replicate the issue by changing to the process work dir and entering the command `bash .command.run`
#
#  -- Check '.nextflow.log' file for details
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT | 0 of 2
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 21 more processes waiting for tasks…
# Execution cancelled -- Finishing pending tasks before exit
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
# ERROR ~ Error executing process > 'NFCORE_RNASEQ:RNASEQ:FASTQ_QC_TRIM_FILTER_SETSTRANDEDNESS:FQ_LINT (Sham-Oxy)'
#
# Caused by:
#   Process requirement exceeds available memory -- req: 12 GB; avail: 7.6 GB
#
#
# Command executed:
#
#   fq lint \
#       --disable-validator P001 \
#       SRX19144488_SRR23195511_1.fastq.gz SRX19144488_SRR23195511_2.fastq.gz > Sham-Oxy.fq_lint.txt
#
#   cat <<-END_VERSIONS > versions.yml
#   "NFCORE_RNASEQ:RNASEQ:FASTQ_QC_TRIM_FILTER_SETSTRANDEDNESS:FQ_LINT":
#       fq: $(echo $(fq lint --version | sed 's/fq-lint //g'))
#   END_VERSIONS
#
# Command exit status:
#   -
#
# Command output:
#   (empty)
#
# Work dir:
#   /home/mj/nf-pipelines/computational-workflows-2025/notebooks/day_02/work/3b/469f2a596f308dd8727be827d94075
#
# Container:
#   /home/mj/nf-pipelines/computational-workflows-2025/notebooks/day_02/work/singularity/quay.io-biocontainers-fq-0.12.0--h9ee0642_0.img
#
# Tip: you can replicate the issue by changing to the process work dir and entering the command `bash .command.run`
#
#  -- Check '.nextflow.log' file for details
# ERROR ~ Pipeline failed. Please refer to troubleshooting docs: https://nf-co.re/docs/usage/troubleshooting
#
#  -- Check '.nextflow.log' file for details
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [3b/469f2a] NFC…DEDNESS:FQ_LINT (Sham-Oxy) | 0 of 2
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 21 more processes waiting for tasks…
# Execution cancelled -- Finishing pending tasks before exit
# -[nf-core/rnaseq] Pipeline completed with errors-
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
# ERROR ~ Error executing process > 'NFCORE_RNASEQ:RNASEQ:FASTQ_QC_TRIM_FILTER_SETSTRANDEDNESS:FQ_LINT (Sham-Oxy)'
#
# Caused by:
#   Process requirement exceeds available memory -- req: 12 GB; avail: 7.6 GB
#
#
# Command executed:
#
#   fq lint \
#       --disable-validator P001 \
#       SRX19144488_SRR23195511_1.fastq.gz SRX19144488_SRR23195511_2.fastq.gz > Sham-Oxy.fq_lint.txt
#
#   cat <<-END_VERSIONS > versions.yml
#   "NFCORE_RNASEQ:RNASEQ:FASTQ_QC_TRIM_FILTER_SETSTRANDEDNESS:FQ_LINT":
#       fq: $(echo $(fq lint --version | sed 's/fq-lint //g'))
#   END_VERSIONS
#
# Command exit status:
#   -
#
# Command output:
#   (empty)
#
# Work dir:
#   /home/mj/nf-pipelines/computational-workflows-2025/notebooks/day_02/work/3b/469f2a596f308dd8727be827d94075
#
# Container:
#   /home/mj/nf-pipelines/computational-workflows-2025/notebooks/day_02/work/singularity/quay.io-biocontainers-fq-0.12.0--h9ee0642_0.img
#
# Tip: you can replicate the issue by changing to the process work dir and entering the command `bash .command.run`
#
#  -- Check '.nextflow.log' file for details
# ERROR ~ Pipeline failed. Please refer to troubleshooting docs: https://nf-co.re/docs/usage/troubleshooting
#
#  -- Check '.nextflow.log' file for details
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [3b/469f2a] NFC…DEDNESS:FQ_LINT (Sham-Oxy) | 0 of 2
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…N_STAR:STAR_ALIGN_IGENOMES -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# [-        ] NFC…Y_STAR_SALMON:SALMON_QUANT -
# [-        ] NFC…STAR_SALMON:CUSTOM_TX2GENE -
# Plus 21 more processes waiting for tasks…
# Execution cancelled -- Finishing pending tasks before exit
# -[nf-core/rnaseq] Pipeline completed with errors-
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
# ERROR ~ Error executing process > 'NFCORE_RNASEQ:RNASEQ:FASTQ_QC_TRIM_FILTER_SETSTRANDEDNESS:FQ_LINT (Sham-Oxy)'
#
# Caused by:
#   Process requirement exceeds available memory -- req: 12 GB; avail: 7.6 GB
#
#
# Command executed:
#
#   fq lint \
#       --disable-validator P001 \
#       SRX19144488_SRR23195511_1.fastq.gz SRX19144488_SRR23195511_2.fastq.gz > Sham-Oxy.fq_lint.txt
#
#   cat <<-END_VERSIONS > versions.yml
#   "NFCORE_RNASEQ:RNASEQ:FASTQ_QC_TRIM_FILTER_SETSTRANDEDNESS:FQ_LINT":
#       fq: $(echo $(fq lint --version | sed 's/fq-lint //g'))
#   END_VERSIONS
#
# Command exit status:
#   -
#
# Command output:
#   (empty)
#
# Work dir:
#   /home/mj/nf-pipelines/computational-workflows-2025/notebooks/day_02/work/3b/469f2a596f308dd8727be827d94075
#
# Container:
#   /home/mj/nf-pipelines/computational-workflows-2025/notebooks/day_02/work/singularity/quay.io-biocontainers-fq-0.12.0--h9ee0642_0.img
#
# Tip: you can replicate the issue by changing to the process work dir and entering the command `bash .command.run`
#
#  -- Check '.nextflow.log' file for details
# ERROR ~ Pipeline failed. Please refer to troubleshooting docs: https://nf-co.re/docs/usage/troubleshooting
#
#  -- Check '.nextflow.log' file for details
# Staging foreign file: s3://ngi-igenomes/igenomes/Mus_musculus/Ensembl/GRCm38/Sequence/WholeGenomeFasta/genome.fa
# Staging foreign file: s3://ngi-igenomes/igenomes/Mus_musculus/Ensembl/GRCm38/Annotation/Genes/genes.gtf
# Waiting for file transfers to complete (2 files)
# ERROR ~ Pipeline failed. Please refer to troubleshooting docs: https://nf-co.re/docs/usage/troubleshooting
#
#  -- Check '.nextflow.log' file for details
#
# One more CTRL+C to force exit

# %% [markdown]
# Explain all the parameters you set and why you set them in this way.

# %% [markdown]
# ## Browsing the results

# %% [markdown]
# How did the pipeline perform?

# %% [markdown]
# Didn't perform due to memory issues. Tried the config file but doesn't work with apptainer for now.

# %% [markdown]
# Explain the quality control steps. Are you happy with the quality and why. If not, why not.
# Please give additional information on :
# - ribosomal rRNA
# - Duplication
# - GC content
#
# What are the possible steps that could lead to poorer results?

# %% [markdown]
# Would you exclude any samples? If yes, which and why?

# %% [markdown]
# What would you now do to continue the experiment? What are the scientists trying to figure out? Which packages on R or python would you use?
