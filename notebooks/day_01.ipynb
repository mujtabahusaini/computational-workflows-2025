# %% [markdown]
# # Computational Workflows for biomedical data

# %% [markdown]
# Welcome to the course Computational Workflows for Biomedical Data. Over the next two weeks, you will learn how to leverage nf-core pipelines to analyze biomedical data and gain hands-on experience in creating your own pipelines, with a strong emphasis on Nextflow and nf-core.
#
# Course Structure:
#
# - Week 1: You will use a variety of nf-core pipelines to analyze a publicly available biomedical study.
# - Week 2: We will shift focus to learning the basics of Nextflow, enabling you to design and implement your own computational workflows.<br>
# - Final Project: The last couple of days, you will apply your knowledge to create a custom pipeline for analyzing biomedical data using Nextflow and the nf-core template.

# %% [markdown]
# ## Basics
#
# If you have not installed all required software, please do so now asap!
#
#
# If you already installed all software, please go on and start answering the questions in this notebook. If you have any questions, don't hesitate to approach us.

# %% [markdown]
# 1. What is nf-core?

# %% [markdown]
# nf-core is a community driven collection of best practice bioinformatics pipelines, built with Nextflow.

# %% [markdown]
# 2. How many pipelines are there currently in nf-core?

# %% [markdown]
# 139

# %% [markdown]
# 3. Are there any non-bioinformatic pipelines in nf-core?

# %% [markdown]
# there are a couple like rangeland used for satellite imagery.

# %% [markdown]
# 4. Let's go back a couple of steps. What is a pipeline and what do we use it for?

# %% [markdown]
# Pipeline is a sequence of automated computational steps used to process raw data into results.

# %% [markdown]
# 5. Why do you think nf-core adheres to strict guidelines?

# %% [markdown]
# to ensure reproducibility, portability, and community trust.

# %% [markdown]
# 6. What are the main features of nf-core pipelines?

# %% [markdown]
# Standardised, well-documented, reproducible, portable, and community maintained.

# %% [markdown]
# ## Let's start using the pipelines

# %% [markdown]
# 1. Find the nf-core pipeline used to measure differential abundance of genes

# %%
# run the pipeline in a cell 
# to run bash in jupyter notebooks, simply use ! before the command
# e.g.

# !pwd


# For the tasks in the first week, please use the command line to run your commands and simply paste the commands you used in the respective cells!

# %%
# run the pipeline in the test profile using docker containers
# make sure to specify the version you want to use (use the latest one)


# !nextflow run nf-core/differentialabundance -profile test,apptainer --outdir ~/nf-results --gtf /home/mj/nf-pipelines/computational-workflows-2025/Mus_musculus.GRCm38.81.gtf.gz
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/differentialabundance` [crazy_liskov] DSL2 - revision: 3dd360fed0 [master]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/differentialabundance v1.5.0-g3dd360f
# ------------------------------------------------------
# Core Nextflow options
#   revision                    : master
#   runName                     : crazy_liskov
#   containerEngine             : apptainer
#   container                   : [RMARKDOWNNOTEBOOK:biocontainers/r-shinyngs:1.8.8--r43hdfd78af_0]
#   launchDir                   : /home/mj/nf-pipelines/computational-workflows-2025/notebooks/day_01
#   workDir                     : /home/mj/nf-pipelines/computational-workflows-2025/notebooks/day_01/work
#   projectDir                  : /home/mj/.nextflow/assets/nf-core/differentialabundance
#   userName                    : mj
#   profile                     : test,apptainer
#   configFiles                 :
#
# Input/output options
#   study_name                  : SRP254919
#   input                       : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#   contrasts                   : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.contrasts.csv
#   outdir                      : /home/mj/nf-results
#
# Abundance values
#   matrix                      : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.salmon.merged.gene_counts.top1000cov.tsv
#   transcript_length_matrix    : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.spoofed_lengths.tsv
#   affy_cel_files_archive      : null
#   querygse                    : null
#
# Observations (e.g. samples) options
#   observations_name_col       : sample
#
# Affy input options
#   affy_cdfname                : null
#
# Filtering
#   filtering_min_abundance     : 10
#
# Exploratory analysis
#   exploratory_main_variable   : contrasts
#   exploratory_log2_assays     : raw,normalised
#
# Differential analysis
#   differential_file_suffix    : .deseq2.results.tsv
#
# DESeq2 specific options (RNA-seq only)
#   deseq2_vst_nsub             : 500
#
# Limma specific options (microarray only)
#   limma_spacing               : null
#   limma_block                 : null
#   limma_correlation           : null
#
# GSEA
#   gsea_run                    : true
#
# gprofiler2
#   gprofiler2_correction_method: gSCS
#   gprofiler2_background_file  : auto
#
# Shiny app settings
#   shinyngs_shinyapps_account  : null
#   shinyngs_shinyapps_app_name : null
#
# Options related to gene set analysis
#   gene_sets_files             : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/gene_set_analysis/mh.all.v2022.1.Mm.symbols.gmt
#
# Reporting options
#   report_title                : null
#   report_author               : null
#   report_contributors         : Jane Doe
# Director of Institute of Microbiology
# University of Smallville;John Smith
# PhD student
# Institute of Microbiology
# University of Smallville
#   report_description          : null
#   report_round_digits         : 3
#
# Reference genome options
#   gtf                         : /home/mj/nf-pipelines/computational-workflows-2025/Mus_musculus.GRCm38.81.gtf.gz
#
# Institutional config options
#   config_profile_name         : Test profile
#   config_profile_description  : Minimal test dataset to check pipeline function
#
# Max job request options
#   max_cpus                    : 2
#   max_memory                  : 6.GB
#   max_time                    : 6.h
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use nf-core/differentialabundance for your analysis please cite:
#
# * The pipeline
#   https://doi.org/10.5281/zenodo.7568000
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/nf-core/differentialabundance/blob/master/CITATIONS.md
# ------------------------------------------------------
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 0 of 1
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 0 of 1
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (2)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (2)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 0 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (2)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (3)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 0 of 1
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (3)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 0 of 1
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (4)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS | 0 of 2
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (4)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS | 0 of 2
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (5)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [45/455bfd] NFC…Cherry_hND6_sample_number) | 0 of 2
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (6)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (7)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (7)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (7)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (8)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM | 0 of 1
# [bb/a459c5] NFC…, blocking:sample_number]) | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (9)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM | 0 of 1
# [bb/a459c5] NFC…, blocking:sample_number]) | 1 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (10)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [96/f1ff83] NFC…, target:hND6, blocking:]) | 0 of 1
# [bb/a459c5] NFC…, blocking:sample_number]) | 1 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (10)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [96/f1ff83] NFC…, target:hND6, blocking:]) | 0 of 1
# [05/d27d2b] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (11)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [96/f1ff83] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [05/d27d2b] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [c0/a954af] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (11)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [96/f1ff83] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [05/d27d2b] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [c0/a954af] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (12)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [96/f1ff83] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [05/d27d2b] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [b1/a069af] NFC…DANCE:FILTER_DIFFTABLE (2) | 1 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (12)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [96/f1ff83] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [05/d27d2b] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [b1/a069af] NFC…DANCE:FILTER_DIFFTABLE (2) | 1 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (13)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [96/f1ff83] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [05/d27d2b] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [b1/a069af] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [d1/177552] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (14)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [96/f1ff83] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [05/d27d2b] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [b1/a069af] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [bd/453727] NFC… (treatment_mCherry_hND6_) | 0 of 1
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [d1/177552] NFC…Cherry_hND6_sample_number) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [96/f1ff83] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [05/d27d2b] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [b1/a069af] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [bd/453727] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [e0/036fe5] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [d1/177552] NFC…Cherry_hND6_sample_number) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [96/f1ff83] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [05/d27d2b] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [b1/a069af] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [bd/453727] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [e0/036fe5] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [d1/177552] NFC…Cherry_hND6_sample_number) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (16)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [96/f1ff83] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [05/d27d2b] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [b1/a069af] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [bd/453727] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [e0/036fe5] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [7e/a7511a] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (16)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [96/f1ff83] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [05/d27d2b] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [b1/a069af] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [bd/453727] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [e0/036fe5] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [7e/a7511a] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (17)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [96/f1ff83] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [05/d27d2b] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [b1/a069af] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [bd/453727] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [e0/036fe5] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [7e/a7511a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [68/000d30] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (17)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [96/f1ff83] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [05/d27d2b] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [b1/a069af] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [bd/453727] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [e0/036fe5] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [7e/a7511a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [68/000d30] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (18)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [96/f1ff83] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [05/d27d2b] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [b1/a069af] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [bd/453727] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [9a/a570d1] NFC…Cherry_hND6_sample_number) | 0 of 2
# [e0/036fe5] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [7e/a7511a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [68/000d30] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [96/f1ff83] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [05/d27d2b] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [b1/a069af] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [bd/453727] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [72/ed2134] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [e0/036fe5] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [7e/a7511a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [68/000d30] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [96/f1ff83] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [05/d27d2b] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [b1/a069af] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [bd/453727] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [9a/a570d1] NFC…Cherry_hND6_sample_number) | 1 of 2
# [e0/036fe5] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [7e/a7511a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [68/000d30] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [96/f1ff83] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [05/d27d2b] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [b1/a069af] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [bd/453727] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [72/ed2134] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [e0/036fe5] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [7e/a7511a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [68/000d30] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [96/f1ff83] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [05/d27d2b] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [b1/a069af] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [bd/453727] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [72/ed2134] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [e0/036fe5] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [7e/a7511a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [68/000d30] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [9d/f82f47] NFC…RKDOWNNOTEBOOK (SRP254919) | 0 of 1
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (21)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [96/f1ff83] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [05/d27d2b] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [b1/a069af] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [bd/453727] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [72/ed2134] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [e0/036fe5] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [7e/a7511a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [68/000d30] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [9d/f82f47] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [de/62e76b] NFC…_REPORT_BUNDLE (SRP254919) | 0 of 1
#
# executor >  local (21)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [96/f1ff83] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [05/d27d2b] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [b1/a069af] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [bd/453727] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [72/ed2134] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [e0/036fe5] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [7e/a7511a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [68/000d30] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [9d/f82f47] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [de/62e76b] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
#
# executor >  local (21)
# [2f/3d5aeb] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [4f/7274dc] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [04/6c90ac] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [f6/b10b2c] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [96/f1ff83] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [05/d27d2b] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [b1/a069af] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [bd/453727] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [80/4efc85] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d1/49d375] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [72/ed2134] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [e0/036fe5] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [7e/a7511a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [68/000d30] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [9d/f82f47] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [de/62e76b] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
# Completed at: 29-Sep-2025 17:31:50
# Duration    : 4m 41s
# CPU hours   : 0.1
# Succeeded   : 21

# %%
# repeat the run. What did change? -> Took much shorter run time.
# !nextflow run nf-core/differentialabundance -profile test,apptainer --outdir ~/nf-results --gtf /home/mj/nf-pipelines/computational-workflows-2025/Mus_musculus.GRCm38.81.gtf.gz
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/differentialabundance` [marvelous_wescoff] DSL2 - revision: 3dd360fed0 [master]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/differentialabundance v1.5.0-g3dd360f
# ------------------------------------------------------
# Core Nextflow options
#   revision                    : master
#   runName                     : marvelous_wescoff
#   containerEngine             : apptainer
#   container                   : [RMARKDOWNNOTEBOOK:biocontainers/r-shinyngs:1.8.8--r43hdfd78af_0]
#   launchDir                   : /home/mj/nf-pipelines/computational-workflows-2025/notebooks/day_01
#   workDir                     : /home/mj/nf-pipelines/computational-workflows-2025/notebooks/day_01/work
#   projectDir                  : /home/mj/.nextflow/assets/nf-core/differentialabundance
#   userName                    : mj
#   profile                     : test,apptainer
#   configFiles                 :
#
# Input/output options
#   study_name                  : SRP254919
#   input                       : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#   contrasts                   : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.contrasts.csv
#   outdir                      : /home/mj/nf-results
#
# Abundance values
#   matrix                      : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.salmon.merged.gene_counts.top1000cov.tsv
#   transcript_length_matrix    : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.spoofed_lengths.tsv
#   affy_cel_files_archive      : null
#   querygse                    : null
#
# Observations (e.g. samples) options
#   observations_name_col       : sample
#
# Affy input options
#   affy_cdfname                : null
#
# Filtering
#   filtering_min_abundance     : 10
#
# Exploratory analysis
#   exploratory_main_variable   : contrasts
#   exploratory_log2_assays     : raw,normalised
#
# Differential analysis
#   differential_file_suffix    : .deseq2.results.tsv
#
# DESeq2 specific options (RNA-seq only)
#   deseq2_vst_nsub             : 500
#
# Limma specific options (microarray only)
#   limma_spacing               : null
#   limma_block                 : null
#   limma_correlation           : null
#
# GSEA
#   gsea_run                    : true
#
# gprofiler2
#   gprofiler2_correction_method: gSCS
#   gprofiler2_background_file  : auto
#
# Shiny app settings
#   shinyngs_shinyapps_account  : null
#   shinyngs_shinyapps_app_name : null
#
# Options related to gene set analysis
#   gene_sets_files             : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/gene_set_analysis/mh.all.v2022.1.Mm.symbols.gmt
#
# Reporting options
#   report_title                : null
#   report_author               : null
#   report_contributors         : Jane Doe
# Director of Institute of Microbiology
# University of Smallville;John Smith
# PhD student
# Institute of Microbiology
# University of Smallville
#   report_description          : null
#   report_round_digits         : 3
#
# Reference genome options
#   gtf                         : /home/mj/nf-pipelines/computational-workflows-2025/Mus_musculus.GRCm38.81.gtf.gz
#
# Institutional config options
#   config_profile_name         : Test profile
#   config_profile_description  : Minimal test dataset to check pipeline function
#
# Max job request options
#   max_cpus                    : 2
#   max_memory                  : 6.GB
#   max_time                    : 6.h
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use nf-core/differentialabundance for your analysis please cite:
#
# * The pipeline
#   https://doi.org/10.5281/zenodo.7568000
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/nf-core/differentialabundance/blob/master/CITATIONS.md
# ------------------------------------------------------
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 0 of 1
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (2)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (2)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (3)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 0 of 1
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (3)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 0 of 1
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (3)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (4)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS | 0 of 2
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (5)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [8e/d7d9f4] NFC…Cherry_hND6_sample_number) | 0 of 2
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (6)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [fa/de063a] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (7)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [fa/de063a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (7)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [fa/de063a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (8)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM | 0 of 1
# [a7/ee5091] NFC…, target:hND6, blocking:]) | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [fa/de063a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (9)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 0 of 1
# [a7/ee5091] NFC…, target:hND6, blocking:]) | 1 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [fa/de063a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (9)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 0 of 1
# [a7/ee5091] NFC…, target:hND6, blocking:]) | 1 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [fa/de063a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (10)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [48/a0be3b] NFC…, blocking:sample_number]) | 1 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [fa/de063a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 1
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (10)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [48/a0be3b] NFC…, blocking:sample_number]) | 1 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [fa/de063a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 1
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (11)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [48/a0be3b] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [8b/ede778] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [fa/de063a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (12)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [48/a0be3b] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [8b/ede778] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [fa/de063a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [fe/79a776] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (12)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [48/a0be3b] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [8b/ede778] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [fa/de063a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [fe/79a776] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (13)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [48/a0be3b] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [8b/ede778] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [fa/de063a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [e6/4a433b] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [fe/79a776] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (14)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [48/a0be3b] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [8b/ede778] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [a4/a9016f] NFC… (treatment_mCherry_hND6_) | 0 of 1
# [fa/de063a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [e6/4a433b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [fe/79a776] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [48/a0be3b] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [34/27c7e8] NFC…DANCE:FILTER_DIFFTABLE (2) | 1 of 2
# [a4/a9016f] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [fa/de063a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [e6/4a433b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [fe/79a776] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [48/a0be3b] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [34/27c7e8] NFC…DANCE:FILTER_DIFFTABLE (2) | 1 of 2
# [a4/a9016f] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [fa/de063a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [e6/4a433b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [fe/79a776] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (16)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [48/a0be3b] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [34/27c7e8] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [a4/a9016f] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [fa/de063a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [e6/4a433b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [35/c5a8c3] NFC…Cherry_hND6_sample_number) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (17)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [48/a0be3b] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [34/27c7e8] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [a4/a9016f] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [fa/de063a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [e6/4a433b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [35/c5a8c3] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [db/94aad4] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (17)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [48/a0be3b] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [34/27c7e8] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [a4/a9016f] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [fa/de063a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [e6/4a433b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [35/c5a8c3] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [db/94aad4] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (18)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [48/a0be3b] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [34/27c7e8] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [a4/a9016f] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [fa/de063a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [c3/713227] NFC…Cherry_hND6_sample_number) | 0 of 2
# [e6/4a433b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [35/c5a8c3] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [db/94aad4] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [48/a0be3b] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [34/27c7e8] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [a4/a9016f] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [fa/de063a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [c3/713227] NFC…Cherry_hND6_sample_number) | 1 of 2
# [e6/4a433b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [35/c5a8c3] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [db/94aad4] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [48/a0be3b] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [34/27c7e8] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [a4/a9016f] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [fa/de063a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [61/a4ccec] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [e6/4a433b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [35/c5a8c3] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [db/94aad4] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [48/a0be3b] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [34/27c7e8] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [a4/a9016f] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [fa/de063a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [61/a4ccec] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [e6/4a433b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [35/c5a8c3] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [db/94aad4] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [9c/8ebc68] NFC…RKDOWNNOTEBOOK (SRP254919) | 0 of 1
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (21)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [48/a0be3b] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [34/27c7e8] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [a4/a9016f] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [fa/de063a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [61/a4ccec] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [e6/4a433b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [35/c5a8c3] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [db/94aad4] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [9c/8ebc68] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [dc/5b1b5f] NFC…_REPORT_BUNDLE (SRP254919) | 0 of 1
#
# executor >  local (21)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [48/a0be3b] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [34/27c7e8] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [a4/a9016f] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [fa/de063a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [61/a4ccec] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [e6/4a433b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [35/c5a8c3] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [db/94aad4] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [9c/8ebc68] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [dc/5b1b5f] NFC…_REPORT_BUNDLE (SRP254919) | 0 of 1
#
# executor >  local (21)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [48/a0be3b] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [34/27c7e8] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [a4/a9016f] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [fa/de063a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [61/a4ccec] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [e6/4a433b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [35/c5a8c3] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [db/94aad4] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [9c/8ebc68] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [dc/5b1b5f] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
#
# executor >  local (21)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [48/a0be3b] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [34/27c7e8] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [a4/a9016f] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [fa/de063a] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [61/a4ccec] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [e6/4a433b] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [35/c5a8c3] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [db/94aad4] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [9c/8ebc68] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [dc/5b1b5f] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
# Completed at: 29-Sep-2025 14:52:38
# Duration    : 3m 10s
# CPU hours   : 0.1
# Succeeded   : 21

# %%
# now set -resume to the command. What did change? -> super fast only 30s runtime as compared to 3 and 10 mins earlier due to cache use
# !nextflow run nf-core/differentialabundance -profile test,apptainer --outdir ~/nf-results --gtf /home/mj/nf-pipelines/computational-workflows-2025/Mus_musculus.GRCm38.81.gtf.gz -resume
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/differentialabundance` [condescending_yonath] DSL2 - revision: 3dd360fed0 [master]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/differentialabundance v1.5.0-g3dd360f
# ------------------------------------------------------
# Core Nextflow options
#   revision                    : master
#   runName                     : condescending_yonath
#   containerEngine             : apptainer
#   container                   : [RMARKDOWNNOTEBOOK:biocontainers/r-shinyngs:1.8.8--r43hdfd78af_0]
#   launchDir                   : /home/mj/nf-pipelines/computational-workflows-2025/notebooks/day_01
#   workDir                     : /home/mj/nf-pipelines/computational-workflows-2025/notebooks/day_01/work
#   projectDir                  : /home/mj/.nextflow/assets/nf-core/differentialabundance
#   userName                    : mj
#   profile                     : test,apptainer
#   configFiles                 :
#
# Input/output options
#   study_name                  : SRP254919
#   input                       : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#   contrasts                   : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.contrasts.csv
#   outdir                      : /home/mj/nf-results
#
# Abundance values
#   matrix                      : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.salmon.merged.gene_counts.top1000cov.tsv
#   transcript_length_matrix    : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.spoofed_lengths.tsv
#   affy_cel_files_archive      : null
#   querygse                    : null
#
# Observations (e.g. samples) options
#   observations_name_col       : sample
#
# Affy input options
#   affy_cdfname                : null
#
# Filtering
#   filtering_min_abundance     : 10
#
# Exploratory analysis
#   exploratory_main_variable   : contrasts
#   exploratory_log2_assays     : raw,normalised
#
# Differential analysis
#   differential_file_suffix    : .deseq2.results.tsv
#
# DESeq2 specific options (RNA-seq only)
#   deseq2_vst_nsub             : 500
#
# Limma specific options (microarray only)
#   limma_spacing               : null
#   limma_block                 : null
#   limma_correlation           : null
#
# GSEA
#   gsea_run                    : true
#
# gprofiler2
#   gprofiler2_correction_method: gSCS
#   gprofiler2_background_file  : auto
#
# Shiny app settings
#   shinyngs_shinyapps_account  : null
#   shinyngs_shinyapps_app_name : null
#
# Options related to gene set analysis
#   gene_sets_files             : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/gene_set_analysis/mh.all.v2022.1.Mm.symbols.gmt
#
# Reporting options
#   report_title                : null
#   report_author               : null
#   report_contributors         : Jane Doe
# Director of Institute of Microbiology
# University of Smallville;John Smith
# PhD student
# Institute of Microbiology
# University of Smallville
#   report_description          : null
#   report_round_digits         : 3
#
# Reference genome options
#   gtf                         : /home/mj/nf-pipelines/computational-workflows-2025/Mus_musculus.GRCm38.81.gtf.gz
#
# Institutional config options
#   config_profile_name         : Test profile
#   config_profile_description  : Minimal test dataset to check pipeline function
#
# Max job request options
#   max_cpus                    : 2
#   max_memory                  : 6.GB
#   max_time                    : 6.h
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use nf-core/differentialabundance for your analysis please cite:
#
# * The pipeline
#   https://doi.org/10.5281/zenodo.7568000
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/nf-core/differentialabundance/blob/master/CITATIONS.md
# ------------------------------------------------------
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [8e/d7d9f4] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [a7/ee5091] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [8e/d7d9f4] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [a7/ee5091] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [8b/ede778] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [a4/a9016f] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [8e/d7d9f4] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [e6/4a433b] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [35/c5a8c3] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [0d/4a8ffc] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [a7/ee5091] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [8b/ede778] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [a4/a9016f] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [8e/d7d9f4] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [e6/4a433b] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [35/c5a8c3] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [0d/4a8ffc] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [a7/ee5091] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [8b/ede778] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [a4/a9016f] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [8e/d7d9f4] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [61/a4ccec] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [e6/4a433b] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [35/c5a8c3] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [0d/4a8ffc] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [a7/ee5091] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [8b/ede778] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [a4/a9016f] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [8e/d7d9f4] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [61/a4ccec] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [e6/4a433b] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [35/c5a8c3] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [0d/4a8ffc] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [9c/8ebc68] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1, cached: 1 ✔
# [dc/5b1b5f] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1, cached: 1 ✔
#
# executor >  local (1)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [a7/ee5091] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [8b/ede778] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [a4/a9016f] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [8e/d7d9f4] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [61/a4ccec] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [e6/4a433b] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [35/c5a8c3] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [0d/4a8ffc] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [9c/8ebc68] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1, cached: 1 ✔
# [dc/5b1b5f] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1, cached: 1 ✔
#
# executor >  local (1)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [a7/ee5091] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [8b/ede778] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [a4/a9016f] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [8e/d7d9f4] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [61/a4ccec] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [e6/4a433b] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [35/c5a8c3] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [0d/4a8ffc] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [9c/8ebc68] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1, cached: 1 ✔
# [dc/5b1b5f] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1, cached: 1 ✔

# %% [markdown]
# Check out the current directory. Next to the outdir you specified, what else has changed?

# %% [markdown]
# can see log files, output files.

# %%
# delete the work directory and run the pipeline again using -resume. What did change?
# !nextflow run nf-core/differentialabundance -profile test,apptainer --outdir ~/nf-results --gtf /home/mj/nf-pipelines/computational-workflows-2025/Mus_musculus.GRCm38.81.gtf.gz -resume
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/differentialabundance` [boring_leavitt] DSL2 - revision: 3dd360fed0 [master]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/differentialabundance v1.5.0-g3dd360f
# ------------------------------------------------------
# Core Nextflow options
#   revision                    : master
#   runName                     : boring_leavitt
#   containerEngine             : apptainer
#   container                   : [RMARKDOWNNOTEBOOK:biocontainers/r-shinyngs:1.8.8--r43hdfd78af_0]
#   launchDir                   : /home/mj/nf-pipelines/computational-workflows-2025/notebooks/day_01
#   workDir                     : /home/mj/nf-pipelines/computational-workflows-2025/notebooks/day_01/work
#   projectDir                  : /home/mj/.nextflow/assets/nf-core/differentialabundance
#   userName                    : mj
#   profile                     : test,apptainer
#   configFiles                 :
#
# Input/output options
#   study_name                  : SRP254919
#   input                       : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#   contrasts                   : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.contrasts.csv
#   outdir                      : /home/mj/nf-results
#
# Abundance values
#   matrix                      : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.salmon.merged.gene_counts.top1000cov.tsv
#   transcript_length_matrix    : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.spoofed_lengths.tsv
#   affy_cel_files_archive      : null
#   querygse                    : null
#
# Observations (e.g. samples) options
#   observations_name_col       : sample
#
# Affy input options
#   affy_cdfname                : null
#
# Filtering
#   filtering_min_abundance     : 10
#
# Exploratory analysis
#   exploratory_main_variable   : contrasts
#   exploratory_log2_assays     : raw,normalised
#
# Differential analysis
#   differential_file_suffix    : .deseq2.results.tsv
#
# DESeq2 specific options (RNA-seq only)
#   deseq2_vst_nsub             : 500
#
# Limma specific options (microarray only)
#   limma_spacing               : null
#   limma_block                 : null
#   limma_correlation           : null
#
# GSEA
#   gsea_run                    : true
#
# gprofiler2
#   gprofiler2_correction_method: gSCS
#   gprofiler2_background_file  : auto
#
# Shiny app settings
#   shinyngs_shinyapps_account  : null
#   shinyngs_shinyapps_app_name : null
#
# Options related to gene set analysis
#   gene_sets_files             : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/gene_set_analysis/mh.all.v2022.1.Mm.symbols.gmt
#
# Reporting options
#   report_title                : null
#   report_author               : null
#   report_contributors         : Jane Doe
# Director of Institute of Microbiology
# University of Smallville;John Smith
# PhD student
# Institute of Microbiology
# University of Smallville
#   report_description          : null
#   report_round_digits         : 3
#
# Reference genome options
#   gtf                         : /home/mj/nf-pipelines/computational-workflows-2025/Mus_musculus.GRCm38.81.gtf.gz
#
# Institutional config options
#   config_profile_name         : Test profile
#   config_profile_description  : Minimal test dataset to check pipeline function
#
# Max job request options
#   max_cpus                    : 2
#   max_memory                  : 6.GB
#   max_time                    : 6.h
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use nf-core/differentialabundance for your analysis please cite:
#
# * The pipeline
#   https://doi.org/10.5281/zenodo.7568000
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/nf-core/differentialabundance/blob/master/CITATIONS.md
# ------------------------------------------------------
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [8e/d7d9f4] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [48/a0be3b] NFC…, blocking:sample_number]) | 2 of 2, cached: 2 ✔
# [8b/ede778] NFC…DANCE:FILTER_DIFFTABLE (1) | 2 of 2, cached: 2 ✔
# [a4/a9016f] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [8e/d7d9f4] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [35/c5a8c3] NFC…Cherry_hND6_sample_number) | 1 of 1, cached: 1
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [48/a0be3b] NFC…, blocking:sample_number]) | 2 of 2, cached: 2 ✔
# [8b/ede778] NFC…DANCE:FILTER_DIFFTABLE (1) | 2 of 2, cached: 2 ✔
# [a4/a9016f] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [8e/d7d9f4] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [e6/4a433b] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [fe/79a776] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [f4/f1d824] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [48/a0be3b] NFC…, blocking:sample_number]) | 2 of 2, cached: 2 ✔
# [8b/ede778] NFC…DANCE:FILTER_DIFFTABLE (1) | 2 of 2, cached: 2 ✔
# [a4/a9016f] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [8e/d7d9f4] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [61/a4ccec] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [e6/4a433b] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [fe/79a776] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [f4/f1d824] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [48/a0be3b] NFC…, blocking:sample_number]) | 2 of 2, cached: 2 ✔
# [8b/ede778] NFC…DANCE:FILTER_DIFFTABLE (1) | 2 of 2, cached: 2 ✔
# [a4/a9016f] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [8e/d7d9f4] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [61/a4ccec] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [e6/4a433b] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [fe/79a776] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [f4/f1d824] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [9c/8ebc68] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1, cached: 1 ✔
# [dc/5b1b5f] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1, cached: 1 ✔
#
# executor >  local (1)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [48/a0be3b] NFC…, blocking:sample_number]) | 2 of 2, cached: 2 ✔
# [8b/ede778] NFC…DANCE:FILTER_DIFFTABLE (1) | 2 of 2, cached: 2 ✔
# [a4/a9016f] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [8e/d7d9f4] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [61/a4ccec] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [e6/4a433b] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [fe/79a776] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [f4/f1d824] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [9c/8ebc68] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1, cached: 1 ✔
# [dc/5b1b5f] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1, cached: 1 ✔
#
# executor >  local (1)
# [90/28139c] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [53/8ca46f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [81/69fc7c] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [13/b8f833] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [10/c98e51] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [48/a0be3b] NFC…, blocking:sample_number]) | 2 of 2, cached: 2 ✔
# [8b/ede778] NFC…DANCE:FILTER_DIFFTABLE (1) | 2 of 2, cached: 2 ✔
# [a4/a9016f] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [8e/d7d9f4] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [23/263d5c] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [61/a4ccec] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [e6/4a433b] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [fe/79a776] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [f4/f1d824] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [9c/8ebc68] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1, cached: 1 ✔
# [dc/5b1b5f] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1, cached: 1 ✔

# %% [markdown]
# What changed?

# %% [markdown]
# ## Lets look at the results

# %% [markdown]
# ### What is differential abundance analysis?

# %% [markdown]
# differential abundance is a bioinformatics pipeline that can be used to analyse data represented as matrices, comparing groups of observations to generate differential statistics and downstream analyses

# %% [markdown]
# Give the most important plots from the report:

# %%
from IPython.display import Image

Image(filename="/home/mj/nf-results/plots/differential/treatment_mCherry_hND6_/png/volcano.png")

# %%
from IPython.display import Image

Image(filename="/home/mj/nf-results/plots/qc/treatment_mCherry_hND6_.deseq2.dispersion.png")
