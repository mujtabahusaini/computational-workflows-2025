# %% [markdown]
# # A short introduction to containerized software
#
# After spending time using nf-core pipelines to answer bioinformatic questions, we will focus on the processes that lie behind these pipelines now.
#
# Today, we will focus on containerization, namely via Docker.

# %% [markdown]
# 1. Check if Docker is installed.

# %%
# !docker info
# Out:
# Client:
#  Version:    28.3.3-1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  0.27.0-1
#     Path:     /usr/libexec/docker/cli-plugins/docker-buildx
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.39.2
#     Path:     /usr/libexec/docker/cli-plugins/docker-compose
#
# Server:
#  Containers: 1
#   Running: 1
#   Paused: 0
#   Stopped: 0
#  Images: 1
#  Server Version: 24.0.9-2
#  Storage Driver: overlay2
#   Backing Filesystem: extfs
#   Supports d_type: true
#   Using metacopy: false
#   Native Overlay Diff: false
#   userxattr: false
#  Logging Driver: json-file
#  Cgroup Driver: systemd
#  Cgroup Version: 2
#  Plugins:
#   Volume: local
#   Network: bridge host ipvlan macvlan null overlay
#   Log: awslogs fluentd gcplogs gelf journald json-file local logentries splunk syslog
#  Swarm: inactive
#  Runtimes: runc io.containerd.runc.v2
#  Default Runtime: runc
#  Init Binary: docker-init
#  containerd version: 05044ec0a9a75232cad458027ca83437aae3f4da
#  runc version: bc20cb4497af9af01bea4a8044f1678ffca2745c
#  init version: de40ad0
#  Security Options:
#   apparmor
#   seccomp
#    Profile: builtin
#   cgroupns
#  Kernel Version: 6.8.0-1030-azure
#  Operating System: Ubuntu 22.04.5 LTS
#  OSType: linux
#  Architecture: x86_64
#  CPUs: 4
#  Total Memory: 15.62GiB
#  Name: 5b893257-769c-4d71-acd7-4e7dd489e78b
#  ID: 62c42d39-2540-4102-8938-016e6b53a8b2
#  Docker Root Dir: /var/lib/docker
#  Debug Mode: false
#  Username: codespacesdev
#  Experimental: false
#  Insecure Registries:
#   127.0.0.0/8
#  Live Restore Enabled: false

# %% [markdown]
# ### What is a container?

# %% [markdown]
# ### Why do we use containers?

# %% [markdown]
# ### What is a docker image?

# %% [markdown]
# ### Let's run our first docker image:

# %% [markdown]
# ### Login to docker

# %%
# This you need to do on the command line directly

# %% [markdown]
# ### Run your first docker container

# %%
# !docker run hello-world
# Out:
# Unable to find image 'hello-world:latest' locally
# latest: Pulling from library/hello-world
#
# Digest: sha256:54e66cc1dd1fcb1c3c58bd8017914dbed8701e2d8c74d9262e26bd9cc1642d31
# Status: Downloaded newer image for hello-world:latest
#
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
#
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (amd64)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
#
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
#
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
#
# For more examples and ideas, visit:
#  https://docs.docker.com/get-started/

# %% [markdown]
# ### Find the container ID

# %%
# !docker ps -a
# Out:
# CONTAINER ID   IMAGE                        COMMAND                  CREATED         STATUS                     PORTS     NAMES
# 3ef42cc6107c   hello-world                  "/hello"                 2 minutes ago   Exited (0) 2 minutes ago             clever_germain
# 72712a1b2cf6   nfcore/devcontainer:latest   "/bin/sh -c 'echo Co…"   5 minutes ago   Up 5 minutes                         confident_archimedes

# %% [markdown]
# ### Delete the container again, give prove its deleted

# %%
# !docker rm 3ef42cc6107c
# Out:
# 3ef42cc6107c

# %%
# !docker ps -a
# Out:
# CONTAINER ID   IMAGE                        COMMAND                  CREATED         STATUS         PORTS     NAMES
# 72712a1b2cf6   nfcore/devcontainer:latest   "/bin/sh -c 'echo Co…"   6 minutes ago   Up 6 minutes             confident_archimedes

# %% [markdown]
# ### FASTQC is a very useful tool as you've learned last week. Let's try and run it from command line
#
# Link to the software: https://www.bioinformatics.babraham.ac.uk/projects/fastqc/

# %% [markdown]
# Please describe the steps you took to download and run the software for the example fastq file from last week below:

# %% [markdown]
# 1. went to the link, downloaded for windows, also installed on linux via sudo apt.
# 2. Opened the file in fastqc
# ...

# %% [markdown]
# ### Very well, now let's try to make use of its docker container
#
# 1. create a container holding fastqc using seqera containers (https://seqera.io/containers/)
# 2. use the container to generate a fastqc html of the example fastq file

# %%
# pull the container
# !docker pull quay.io/biocontainers/fastqc:0.12.1--hdfd78af_0
# Out:
# 0.12.1--hdfd78af_0: Pulling from biocontainers/fastqc
#
# 6a04cedd: Pulling fs layer
# 45ee6d5d: Pulling fs layer
# Digest: sha256:e194048df39c3145d9b4e0a14f4da20b59d59250465b6f2a9cb698445fd45900[2A
# Status: Downloaded newer image for quay.io/biocontainers/fastqc:0.12.1--hdfd78af_0
# quay.io/biocontainers/fastqc:0.12.1--hdfd78af_0

# %%
# run the container and save the results to a new "fastqc_results" directory

# !docker run --rm \
  -v /workspaces/computational-workflows-2025/notebooks/day_03_part2/:/data \
  -v $(pwd)/fastqc_results:/output \
  quay.io/biocontainers/fastqc:0.12.1--hdfd78af_0 \
  fastqc -o /output /data/SRR23195511_2.fastq
# Out:
# null
# Started analysis of SRR23195511_2.fastq
# Approx 5% complete for SRR23195511_2.fastq
# Approx 10% complete for SRR23195511_2.fastq
# Approx 15% complete for SRR23195511_2.fastq
# Approx 20% complete for SRR23195511_2.fastq
# Approx 25% complete for SRR23195511_2.fastq
# Approx 30% complete for SRR23195511_2.fastq
# Approx 35% complete for SRR23195511_2.fastq
# Approx 40% complete for SRR23195511_2.fastq
# Approx 45% complete for SRR23195511_2.fastq
# Approx 50% complete for SRR23195511_2.fastq
# Approx 55% complete for SRR23195511_2.fastq
# Approx 60% complete for SRR23195511_2.fastq
# Approx 65% complete for SRR23195511_2.fastq
# Approx 70% complete for SRR23195511_2.fastq
# Approx 75% complete for SRR23195511_2.fastq
# Approx 80% complete for SRR23195511_2.fastq
# Approx 85% complete for SRR23195511_2.fastq
# Approx 90% complete for SRR23195511_2.fastq
# Approx 95% complete for SRR23195511_2.fastq
# Analysis complete for SRR23195511_2.fastq

# %%
### Now that you know how to use a docker container, which approach was easier and which approach will be easier in the future?
the docker container was quite easy to use.

# %% [markdown]
# ### What would you say, which approach is more reproducible?

# %% [markdown]
# the docker approach

# %% [markdown]
# ### Compare the file to last weeks fastqc results, are they identical?
# ### Is the fastqc version identical?

# %% [markdown]
# ## Dockerfiles
#
# We now used Docker containers and images directly to boost our research.
#
# Let's create our own toy Dockerfile including the "cowsay" tool (https://en.wikipedia.org/wiki/Cowsay)
#
# Hints:
# 1. Docker is Linux, so you need to know the apt-get command to install "cowsay"

# %%
# !docker build -t cowsay:latest -f cowsay .
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.0s (2/2) FINISHED                                 docker:default
#  => [internal] load build definition from cowsay                           0.0s
#  => => transferring dockerfile: 2B                                         0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
# ERROR: failed to build: failed to solve: failed to read dockerfile: open /var/lib/docker/tmp/buildkit-mount4118251419/cowsay: no such file or directory

# %%
# !docker build -t cowsay:latest -f cowsay .
# Out:
# [+] Building 0.0s (0/2)                                          docker:default
#  => [internal] load .dockerignore                                          0.0s
#  => [internal] load build definition from cowsay                           0.0s
# [+] Building 0.1s (2/2) FINISHED                                 docker:default
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build definition from cowsay                           0.0s
#  => => transferring dockerfile: 2B                                         0.0s
# ERROR: failed to build: failed to solve: failed to read dockerfile: open /var/lib/docker/tmp/buildkit-mount3302518809/cowsay: no such file or directory

# %%
# open the file "my_dockerfile" in a text editor
# !cat my_dockerfile
# Out:
# # this is the base image the container is built on. In this case, it is a slim version of the Debian operating system.
# FROM debian:bullseye-slim
#
# # these are the labels that are added to the image. They are metadata that can be used to identify the author of the image.
# LABEL image.author.name "Mujtaba"
# LABEL image.author.email "husaini.mujtaba@outlook.com"
#
# # !TODO: add the command that is run to install the dependencies for the image. In this case, it should be updating the package list and installing curl and cowsay.
# RUN apt-get update && apt-get install -y cowsay
#
# # !TODO: add an ENV line to set environmental variables. In this case, it should set the PATH variable to /usr/games. Explain in the notebook why this is necessary.
# ENV PATH="/usr/games:$PATH"

# %% [markdown]
# ### Explain the RUN and ENV lines you added to the file

# %% [markdown]
# run is to run the process, and env for the environment variables

# %%
# build the docker image
# !docker build -t my-cowsay -f my_dockerfile .
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.2s (2/3)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.2s
# [+] Building 0.3s (2/4)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.4s (3/4)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.4s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.6s (3/4)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.7s (3/4)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.9s (3/4)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.0s (3/4)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.2s (3/4)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.3s (3/4)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.5s (3/4)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.6s (4/4)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.8s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b 0B / 30.26MB  0.1s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
# [+] Building 1.9s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 13.63MB / 30.26MB  0.2s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
# [+] Building 2.0s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.3s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
# [+] Building 2.1s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.4s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
# [+] Building 2.3s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
# [+] Building 2.4s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  0.1s
# [+] Building 2.5s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  0.2s
# [+] Building 2.6s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  0.3s
# [+] Building 2.7s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  0.4s
# [+] Building 2.8s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  0.5s
# [+] Building 3.0s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  0.6s
# [+] Building 3.1s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  0.8s
# [+] Building 3.2s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  0.9s
# [+] Building 3.3s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.7s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.0s
# [+] Building 3.5s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.1s
# [+] Building 3.6s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
# [+] Building 3.8s (5/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay                  0.2s
# [+] Building 3.9s (5/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay                  0.3s
#  => => # Get:1 http://deb.debian.org/debian bullseye InRelease [75.1 kB]
# [+] Building 4.0s (5/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay                  0.4s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 4.1s (5/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay                  0.5s
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
# [+] Building 4.4s (5/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay                  0.7s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 4.5s (5/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay                  0.9s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 4.7s (5/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay                  1.0s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 4.8s (5/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay                  1.2s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 5.0s (5/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay                  1.3s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 1s (8320 kB/s)
#  => => # Reading package lists...
# [+] Building 5.1s (5/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay                  1.5s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 1s (8320 kB/s)
#  => => # Reading package lists...
# [+] Building 5.3s (5/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay                  1.6s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 1s (8320 kB/s)
#  => => # Reading package lists...
# [+] Building 5.4s (5/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay                  1.7s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 1s (8320 kB/s)
#  => => # Reading package lists...
# [+] Building 5.5s (5/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay                  1.8s
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 1s (8320 kB/s)
#  => => # Reading package lists...
#  => => # Reading package lists...
# [+] Building 5.6s (5/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay                  2.0s
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 1s (8320 kB/s)
#  => => # Reading package lists...
#  => => # Reading package lists...
# [+] Building 5.8s (5/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay                  2.1s
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 1s (8320 kB/s)
#  => => # Reading package lists...
#  => => # Reading package lists...
# ...
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay                  5.3s
#  => => # Setting up libgdbm6:amd64 (1.19-2) ...
#  => => # Setting up libgdbm-compat4:amd64 (1.19-2) ...
#  => => # Setting up libperl5.32:amd64 (5.32.1-4+deb11u4) ...
#  => => # Setting up perl (5.32.1-4+deb11u4) ...
#  => => # Setting up cowsay (3.03+dfsg2-8) ...
#  => => # Processing triggers for libc-bin (2.31-13+deb11u13) ...
# [+] Building 9.1s (5/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay                  5.5s
#  => => # Setting up libgdbm6:amd64 (1.19-2) ...
#  => => # Setting up libgdbm-compat4:amd64 (1.19-2) ...
#  => => # Setting up libperl5.32:amd64 (5.32.1-4+deb11u4) ...
#  => => # Setting up perl (5.32.1-4+deb11u4) ...
#  => => # Setting up cowsay (3.03+dfsg2-8) ...
#  => => # Processing triggers for libc-bin (2.31-13+deb11u13) ...
# [+] Building 9.2s (6/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay                  5.5s
#
#
#
#
#
#
# [+] Building 9.3s (6/7)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay                  5.5s
#  => exporting to image                                                     0.2s
#  => => exporting layers                                                    0.2s
# [+] Building 9.5s (6/7)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay                  5.5s
#  => exporting to image                                                     0.3s
#  => => exporting layers                                                    0.3s
# [+] Building 9.6s (6/7)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay                  5.5s
#  => exporting to image                                                     0.5s
#  => => exporting layers                                                    0.5s
# [+] Building 9.8s (6/7)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay                  5.5s
#  => exporting to image                                                     0.6s
#  => => exporting layers                                                    0.6s
# [+] Building 9.9s (6/7)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay                  5.5s
#  => exporting to image                                                     0.8s
#  => => exporting layers                                                    0.8s
# [+] Building 10.1s (6/7)                                         docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay                  5.5s
#  => exporting to image                                                     0.9s
#  => => exporting layers                                                    0.9s
# [+] Building 10.1s (6/7)                                         docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay                  5.5s
#  => exporting to image                                                     0.9s
#  => => exporting layers                                                    0.9s
# [+] Building 10.1s (7/7) FINISHED                                docker:default
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 808B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 30.26MB / 30.26MB  0.6s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  1.2s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay                  5.5s
#  => exporting to image                                                     0.9s
#  => => exporting layers                                                    0.9s
#  => => writing image sha256:aea6780cda2de7b47c3113661ae6799db4ae9fda1b3f8  0.0s
#  => => naming to docker.io/library/my-cowsay                               0.0s

# %%
# make sure that the image has been built
# !docker images
# Out:
# REPOSITORY                     TAG                  IMAGE ID       CREATED          SIZE
# my-cowsay                      latest               aea6780cda2d   24 seconds ago   145MB
# nfcore/devcontainer            latest               3302bb600cbe   4 weeks ago      2.77GB
# hello-world                    latest               1b44b5a3e06a   7 weeks ago      10.1kB
# quay.io/biocontainers/fastqc   0.12.1--hdfd78af_0   dc85080d4574   2 years ago      614MB

# %%
# run the docker file 
# !docker run my-cowsay cowsay "Hello Docker!"
# Out:
#  _______________
# < Hello Docker! >
#  ---------------
#         \   ^__^
#          \  (oo)\_______
#             (__)\       )\/\
#                 ||----w |
#                 ||     ||

# %% [markdown]
# ## Let's do some bioinformatics with the docker file and create a new docker file that holds the salmon tool used in rnaseq
#
# To do so, use "curl" in your new dockerfile to get salmon from https://github.com/COMBINE-lab/salmon/releases/download/v1.5.2/salmon-1.5.2_linux_x86_64.tar.gz

# %%
# use the file "salmon_docker" in this directory to build a new docker image
# !cat salmon_docker
# Out:
# FROM debian:bullseye-slim
#
# LABEL image.author.name="yourname"
# LABEL image.author.email="yourmail"
#
# # Install dependencies
#
# # Download and install Salmon
#
# # Set the PATH environment variable (to /usr/bin)

# %%
# build the image
# !docker build -t my-salmon -f salmon_docker .
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.2s (2/3)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.2s
# [+] Building 0.3s (2/4)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.4s (3/4)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.4s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.6s (3/4)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.7s (4/4)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.9s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  0.2s
# [+] Building 0.9s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  0.2s
#  => => # Get:1 http://deb.debian.org/debian bullseye InRelease [75.1 kB]
# [+] Building 1.0s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  0.3s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 1.1s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  0.4s
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
# [+] Building 1.4s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  0.7s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 1.5s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  0.8s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 1.7s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  1.0s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 1.8s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  1.1s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 2.0s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  1.2s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 1s (8230 kB/s)
#  => => # Reading package lists...
# [+] Building 2.1s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  1.4s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 1s (8230 kB/s)
#  => => # Reading package lists...
# [+] Building 2.3s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  1.5s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 1s (8230 kB/s)
#  => => # Reading package lists...
# [+] Building 2.3s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  1.6s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 1s (8230 kB/s)
#  => => # Reading package lists...
# [+] Building 2.5s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  1.7s
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 1s (8230 kB/s)
#  => => # Reading package lists...
#  => => # Reading package lists...
# [+] Building 2.6s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  1.9s
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 1s (8230 kB/s)
#  => => # Reading package lists...
#  => => # Reading package lists...
# [+] Building 2.8s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  2.0s
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 1s (8230 kB/s)
#  => => # Reading package lists...
#  => => # Reading package lists...
# [+] Building 2.9s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  2.2s
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 1s (8230 kB/s)
#  => => # Reading package lists...
#  => => # Reading package lists...
# [+] Building 3.0s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  2.3s
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 1s (8230 kB/s)
#  => => # Reading package lists...
#  => => # Reading package lists...
#  => => # Building dependency tree...
#  => => # Reading state information...
# [+] Building 3.2s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  2.4s
#  => => #   libnghttp2-14 libpsl5 librtmp1 libsasl2-2 libsasl2-modules
#  => => #   libsasl2-modules-db libssh2-1 openssl publicsuffix
#  => => # Suggested packages:
#  => => #   libsasl2-modules-gssapi-mit | libsasl2-modules-gssapi-heimdal
#  => => #   libsasl2-modules-ldap libsasl2-modules-otp libsasl2-modules-sql
#  => => # The following NEW packages will be installed:
# [+] Building 3.4s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  2.6s
#  => => # Get:14 http://deb.debian.org/debian bullseye/main amd64 libsasl2-modul
#  => => # es amd64 2.1.27+dfsg-2.1+deb11u1 [104 kB]
#  => => # Get:15 http://deb.debian.org/debian bullseye/main amd64 publicsuffix a
#  => => # ll 20220811.1734-0+deb11u1 [127 kB]
#  => => # debconf: delaying package configuration, since apt-utils is not instal
#  => => # led
# [+] Building 3.5s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  2.8s
#  => => # Fetched 3000 kB in 0s (45.4 MB/s)
#  => => # Selecting previously unselected package openssl.
#  => => # (Reading database ... 6673 files and directories currently installed.)
#  => => # Preparing to unpack .../00-openssl_1.1.1w-0+deb11u3_amd64.deb ...
#  => => # Unpacking openssl (1.1.1w-0+deb11u3) ...
#  => => # Selecting previously unselected package ca-certificates.
# [+] Building 3.6s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  2.9s
#  => => # Preparing to unpack .../01-ca-certificates_20210119_all.deb ...
#  => => # Unpacking ca-certificates (20210119) ...
#  => => # Selecting previously unselected package libbrotli1:amd64.
#  => => # Preparing to unpack .../02-libbrotli1_1.0.9-2+b2_amd64.deb ...
#  => => # Unpacking libbrotli1:amd64 (1.0.9-2+b2) ...
#  => => # Selecting previously unselected package libsasl2-modules-db:amd64.
# [+] Building 3.7s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  3.0s
#  => => # Unpacking libsasl2-2:amd64 (2.1.27+dfsg-2.1+deb11u1) ...
#  => => # Selecting previously unselected package libldap-2.4-2:amd64.
#  => => # Preparing to unpack .../05-libldap-2.4-2_2.4.57+dfsg-3+deb11u1_amd64.d
#  => => # eb ...
#  => => # Unpacking libldap-2.4-2:amd64 (2.4.57+dfsg-3+deb11u1) ...
#  => => # Selecting previously unselected package libnghttp2-14:amd64.
# [+] Building 3.8s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  3.1s
#  => => # 64.deb ...
#  => => # Unpacking librtmp1:amd64 (2.4+20151223.gitfa8646d.1-2+b2) ...
#  => => # Selecting previously unselected package libssh2-1:amd64.
#  => => # Preparing to unpack .../09-libssh2-1_1.9.0-2+deb11u1_amd64.deb ...
#  => => # Unpacking libssh2-1:amd64 (1.9.0-2+deb11u1) ...
#  => => # Selecting previously unselected package libcurl4:amd64.
# [+] Building 3.9s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  3.2s
#  => => # Unpacking curl (7.74.0-1.3+deb11u15) ...
#  => => # Selecting previously unselected package libldap-common.
#  => => # Preparing to unpack .../12-libldap-common_2.4.57+dfsg-3+deb11u1_all.de
#  => => # b ...
#  => => # Unpacking libldap-common (2.4.57+dfsg-3+deb11u1) ...
#  => => # Selecting previously unselected package libsasl2-modules:amd64.
# [+] Building 4.0s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  3.3s
#  => => # Setting up libpsl5:amd64 (0.21.0-1.2) ...
#  => => # Setting up libbrotli1:amd64 (1.0.9-2+b2) ...
#  => => # Setting up libsasl2-modules:amd64 (2.1.27+dfsg-2.1+deb11u1) ...
#  => => # Setting up libnghttp2-14:amd64 (1.43.0-1+deb11u2) ...
#  => => # Setting up libldap-common (2.4.57+dfsg-3+deb11u1) ...
#  => => # Setting up libsasl2-modules-db:amd64 (2.1.27+dfsg-2.1+deb11u1) ...
# [+] Building 4.2s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  3.4s
#  => => # Setting up publicsuffix (20220811.1734-0+deb11u1) ...
#  => => # Setting up libldap-2.4-2:amd64 (2.4.57+dfsg-3+deb11u1) ...
#  => => # Setting up ca-certificates (20210119) ...
#  => => # debconf: unable to initialize frontend: Dialog
#  => => # debconf: (TERM is not set, so the dialog frontend is not usable.)
#  => => # debconf: falling back to frontend: Readline
# [+] Building 4.3s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  3.6s
#  => => # /x86_64-linux-gnu/perl/5.32.1 /usr/local/share/perl/5.32.1 /usr/lib/x8
#  => => # 6_64-linux-gnu/perl5/5.32 /usr/share/perl5 /usr/lib/x86_64-linux-gnu/p
#  => => # erl-base /usr/lib/x86_64-linux-gnu/perl/5.32 /usr/share/perl/5.32 /usr
#  => => # /local/lib/site_perl) at /usr/share/perl5/Debconf/FrontEnd/Readline.pm
#  => => #  line 7.)
#  => => # debconf: falling back to frontend: Teletype
# [+] Building 4.5s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  3.7s
#  => => # /x86_64-linux-gnu/perl/5.32.1 /usr/local/share/perl/5.32.1 /usr/lib/x8
#  => => # 6_64-linux-gnu/perl5/5.32 /usr/share/perl5 /usr/lib/x86_64-linux-gnu/p
#  => => # erl-base /usr/lib/x86_64-linux-gnu/perl/5.32 /usr/share/perl/5.32 /usr
#  => => # /local/lib/site_perl) at /usr/share/perl5/Debconf/FrontEnd/Readline.pm
#  => => #  line 7.)
#  => => # debconf: falling back to frontend: Teletype
# [+] Building 4.5s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  3.8s
#  => => # 6_64-linux-gnu/perl5/5.32 /usr/share/perl5 /usr/lib/x86_64-linux-gnu/p
#  => => # erl-base /usr/lib/x86_64-linux-gnu/perl/5.32 /usr/share/perl/5.32 /usr
#  => => # /local/lib/site_perl) at /usr/share/perl5/Debconf/FrontEnd/Readline.pm
#  => => #  line 7.)
#  => => # debconf: falling back to frontend: Teletype
#  => => # Updating certificates in /etc/ssl/certs...
# [+] Building 4.7s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  3.9s
#  => => # 6_64-linux-gnu/perl5/5.32 /usr/share/perl5 /usr/lib/x86_64-linux-gnu/p
#  => => # erl-base /usr/lib/x86_64-linux-gnu/perl/5.32 /usr/share/perl/5.32 /usr
#  => => # /local/lib/site_perl) at /usr/share/perl5/Debconf/FrontEnd/Readline.pm
#  => => #  line 7.)
#  => => # debconf: falling back to frontend: Teletype
#  => => # Updating certificates in /etc/ssl/certs...
# [+] Building 4.8s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  4.1s
#  => => # 6_64-linux-gnu/perl5/5.32 /usr/share/perl5 /usr/lib/x86_64-linux-gnu/p
#  => => # erl-base /usr/lib/x86_64-linux-gnu/perl/5.32 /usr/share/perl/5.32 /usr
#  => => # /local/lib/site_perl) at /usr/share/perl5/Debconf/FrontEnd/Readline.pm
#  => => #  line 7.)
#  => => # debconf: falling back to frontend: Teletype
#  => => # Updating certificates in /etc/ssl/certs...
# [+] Building 5.0s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  4.2s
#  => => # 6_64-linux-gnu/perl5/5.32 /usr/share/perl5 /usr/lib/x86_64-linux-gnu/p
#  => => # erl-base /usr/lib/x86_64-linux-gnu/perl/5.32 /usr/share/perl/5.32 /usr
#  => => # /local/lib/site_perl) at /usr/share/perl5/Debconf/FrontEnd/Readline.pm
#  => => #  line 7.)
#  => => # debconf: falling back to frontend: Teletype
#  => => # Updating certificates in /etc/ssl/certs...
# [+] Building 5.0s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  4.3s
#  => => # erl-base /usr/lib/x86_64-linux-gnu/perl/5.32 /usr/share/perl/5.32 /usr
#  => => # /local/lib/site_perl) at /usr/share/perl5/Debconf/FrontEnd/Readline.pm
#  => => #  line 7.)
#  => => # debconf: falling back to frontend: Teletype
#  => => # Updating certificates in /etc/ssl/certs...
#  => => # 129 added, 0 removed; done.
# [+] Building 5.2s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  4.5s
#  => => # 129 added, 0 removed; done.
#  => => # Setting up libcurl4:amd64 (7.74.0-1.3+deb11u15) ...
#  => => # Setting up curl (7.74.0-1.3+deb11u15) ...
#  => => # Processing triggers for libc-bin (2.31-13+deb11u13) ...
#  => => # Processing triggers for ca-certificates (20210119) ...
#  => => # Updating certificates in /etc/ssl/certs...
# [+] Building 5.4s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  4.7s
#  => => # 129 added, 0 removed; done.
#  => => # Setting up libcurl4:amd64 (7.74.0-1.3+deb11u15) ...
#  => => # Setting up curl (7.74.0-1.3+deb11u15) ...
#  => => # Processing triggers for libc-bin (2.31-13+deb11u13) ...
#  => => # Processing triggers for ca-certificates (20210119) ...
#  => => # Updating certificates in /etc/ssl/certs...
# [+] Building 5.5s (5/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  4.8s
#  => => # Setting up curl (7.74.0-1.3+deb11u15) ...
#  => => # Processing triggers for libc-bin (2.31-13+deb11u13) ...
#  => => # Processing triggers for ca-certificates (20210119) ...
#  => => # Updating certificates in /etc/ssl/certs...
#  => => # 0 added, 0 removed; done.
#  => => # Running hooks in /etc/ca-certificates/update.d...
# [+] Building 5.6s (6/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  4.9s
#
#
#
#
#
#
# [+] Building 5.8s (6/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  4.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  0.2s
# [+] Building 5.8s (6/7)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  4.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  0.2s
# ...
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  4.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  5.6s
#  => => # --     0
#  => => #   0 51.0M    0     0    0     0      0      0 --:--:-- --:--:-- --:--:
#  => => #  39 51.0M   39 20.0M    0     0  13.9M      0  0:00:03  0:00:01  0:00:
#  => => #  78 51.0M   78 40.0M    0     0  16.9M      0  0:00:03  0:00:02  0:00:
#  => => # 100 51.0M  100 51.0M    0     0  19.4M      0  0:00:02  0:00:02 --:--:
#  => => # -- 22.3M
# [+] Building 11.4s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  4.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  5.8s
#  => => # --     0
#  => => #   0 51.0M    0     0    0     0      0      0 --:--:-- --:--:-- --:--:
#  => => #  39 51.0M   39 20.0M    0     0  13.9M      0  0:00:03  0:00:01  0:00:
#  => => #  78 51.0M   78 40.0M    0     0  16.9M      0  0:00:03  0:00:02  0:00:
#  => => # 100 51.0M  100 51.0M    0     0  19.4M      0  0:00:02  0:00:02 --:--:
#  => => # -- 22.3M
# [+] Building 11.5s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  4.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  5.9s
#  => => # --     0
#  => => #   0 51.0M    0     0    0     0      0      0 --:--:-- --:--:-- --:--:
#  => => #  39 51.0M   39 20.0M    0     0  13.9M      0  0:00:03  0:00:01  0:00:
#  => => #  78 51.0M   78 40.0M    0     0  16.9M      0  0:00:03  0:00:02  0:00:
#  => => # 100 51.0M  100 51.0M    0     0  19.4M      0  0:00:02  0:00:02 --:--:
#  => => # -- 22.3M
# [+] Building 11.7s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  4.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  6.1s
#  => => # --     0
#  => => #   0 51.0M    0     0    0     0      0      0 --:--:-- --:--:-- --:--:
#  => => #  39 51.0M   39 20.0M    0     0  13.9M      0  0:00:03  0:00:01  0:00:
#  => => #  78 51.0M   78 40.0M    0     0  16.9M      0  0:00:03  0:00:02  0:00:
#  => => # 100 51.0M  100 51.0M    0     0  19.4M      0  0:00:02  0:00:02 --:--:
#  => => # -- 22.3M
# [+] Building 11.8s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  4.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  6.2s
#  => => # --     0
#  => => #   0 51.0M    0     0    0     0      0      0 --:--:-- --:--:-- --:--:
#  => => #  39 51.0M   39 20.0M    0     0  13.9M      0  0:00:03  0:00:01  0:00:
#  => => #  78 51.0M   78 40.0M    0     0  16.9M      0  0:00:03  0:00:02  0:00:
#  => => # 100 51.0M  100 51.0M    0     0  19.4M      0  0:00:02  0:00:02 --:--:
#  => => # -- 22.3M
# [+] Building 12.0s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  4.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  6.4s
#  => => # --     0
#  => => #   0 51.0M    0     0    0     0      0      0 --:--:-- --:--:-- --:--:
#  => => #  39 51.0M   39 20.0M    0     0  13.9M      0  0:00:03  0:00:01  0:00:
#  => => #  78 51.0M   78 40.0M    0     0  16.9M      0  0:00:03  0:00:02  0:00:
#  => => # 100 51.0M  100 51.0M    0     0  19.4M      0  0:00:02  0:00:02 --:--:
#  => => # -- 22.3M
# [+] Building 12.1s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  4.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  6.5s
#  => => # --     0
#  => => #   0 51.0M    0     0    0     0      0      0 --:--:-- --:--:-- --:--:
#  => => #  39 51.0M   39 20.0M    0     0  13.9M      0  0:00:03  0:00:01  0:00:
#  => => #  78 51.0M   78 40.0M    0     0  16.9M      0  0:00:03  0:00:02  0:00:
#  => => # 100 51.0M  100 51.0M    0     0  19.4M      0  0:00:02  0:00:02 --:--:
#  => => # -- 22.3M
# [+] Building 12.3s (7/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  4.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  6.7s
#
#
#
#
#
#
# [+] Building 12.4s (7/8)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  4.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  6.7s
#  => exporting to image                                                     0.2s
#  => => exporting layers                                                    0.2s
# [+] Building 12.6s (7/8)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  4.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  6.7s
#  => exporting to image                                                     0.3s
#  => => exporting layers                                                    0.3s
# [+] Building 12.7s (7/8)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  4.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  6.7s
#  => exporting to image                                                     0.5s
#  => => exporting layers                                                    0.5s
# [+] Building 12.9s (7/8)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  4.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  6.7s
#  => exporting to image                                                     0.6s
#  => => exporting layers                                                    0.6s
# [+] Building 13.0s (7/8)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  4.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  6.7s
#  => exporting to image                                                     0.7s
#  => => exporting layers                                                    0.7s
# [+] Building 13.0s (8/8) FINISHED                                docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 610B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update && apt-get install -y curl && rm -rf /var/li  4.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  6.7s
#  => exporting to image                                                     0.7s
#  => => exporting layers                                                    0.7s
#  => => writing image sha256:2c48cfdba74a24b4794d94777427d84dbc351416ee857  0.0s
#  => => naming to docker.io/library/my-salmon                               0.0s

# %%
# run the docker image to give out the version of salmon
# !docker run my-salmon salmon --version
# Out:
# salmon 1.5.2

# %%
# !docker images
# Out:
# REPOSITORY                     TAG                  IMAGE ID       CREATED              SIZE
# my-salmon                      latest               2c48cfdba74a   About a minute ago   306MB
# <none>                         <none>               5bb957f40af2   16 minutes ago       133MB
# my-cowsay                      latest               aea6780cda2d   21 minutes ago       145MB
# nfcore/devcontainer            latest               3302bb600cbe   4 weeks ago          2.77GB
# hello-world                    latest               1b44b5a3e06a   7 weeks ago          10.1kB
# quay.io/biocontainers/fastqc   0.12.1--hdfd78af_0   dc85080d4574   2 years ago          614MB

# %% [markdown]
# ## Do you think bioinformaticians have to create a docker image every time they want to run a tool?
#
# Find the salmon docker image online and run it on your computer.
#
# What is https://biocontainers.pro/ ?

# %%
# !docker pull combinelab/salmon:latest
# Out:
# latest: Pulling from combinelab/salmon
#
# 7f213c76: Pulling fs layer
# 1ed9ab84: Pulling fs layer
# 0bdd40c3: Pulling fs layer
# 893c1bc1: Pulling fs layer
# Digest: sha256:cefd8bb0b2ed9b07f22b5f0fc317ddda540e5b0dc00810d1ff0d92fee5d80370[1A
# Status: Downloaded newer image for combinelab/salmon:latest
# docker.io/combinelab/salmon:latest

# %%
# !docker run --rm combinelab/salmon:latest salmon --version
# Out:
# salmon 1.10.3

# %%
# !docker images
# Out:
# REPOSITORY                     TAG                  IMAGE ID       CREATED          SIZE
# my-salmon                      latest               2c48cfdba74a   13 minutes ago   306MB
# <none>                         <none>               5bb957f40af2   29 minutes ago   133MB
# my-cowsay                      latest               aea6780cda2d   34 minutes ago   145MB
# nfcore/devcontainer            latest               3302bb600cbe   4 weeks ago      2.77GB
# hello-world                    latest               1b44b5a3e06a   7 weeks ago      10.1kB
# combinelab/salmon              latest               3291c6f6c42d   18 months ago    101MB
# quay.io/biocontainers/fastqc   0.12.1--hdfd78af_0   dc85080d4574   2 years ago      614MB

# %% [markdown]
# ## Are there other ways to create Docker (or Apptainer) images?
#
# What is https://seqera.io/containers/ ?
